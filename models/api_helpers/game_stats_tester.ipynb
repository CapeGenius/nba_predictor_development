# %%
import os
filepath = os.path.abspath('')
dirname = os.path.dirname(filepath)
os.chdir(dirname)
from api_helpers.game_stats_helpers import load_past_n_games

load_past_n_games()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 dirname = os.path.dirname(filepath)
#       4 os.chdir(dirname)
# ----> 5 from api_helpers.game_stats_helpers import load_past_n_games
#       7 load_past_n_games()
#
# File ~/Desktop/nba_predictor_development/models/api_helpers/game_stats_helpers.py:2
#       1 from nba_api.stats.static import teams
# ----> 2 from api_helpers.team_stats_helpers import find_team_id
#       3 from nba_api.stats.endpoints import boxscoretraditionalv2
#       4 from nba_api.stats.endpoints import leaguegamefinder
#
# File ~/Desktop/nba_predictor_development/models/api_helpers/team_stats_helpers.py:6
#       1 """
#       2 Helper file that contains functions to use the NBA
#       3 api, process the data, and organize and plot the data
#       4 """
# ----> 6 from nba_api.stats.endpoints import teamyearbyyearstats
#       7 from nba_api.stats.static import teams
#       8 import pandas as pd
#
# File /opt/homebrew/lib/python3.9/site-packages/nba_api/stats/endpoints/__init__.py:140
#       1 __all__ = [
#       2     "alltimeleadersgrids",
#       3     "assistleaders",
#    (...)
#     137     "winprobabilitypbp",
#     138 ]
# --> 140 from .alltimeleadersgrids import AllTimeLeadersGrids
#     141 from .assistleaders import AssistLeaders
#     142 from .assisttracker import AssistTracker
#
# File /opt/homebrew/lib/python3.9/site-packages/nba_api/stats/endpoints/alltimeleadersgrids.py:1
# ----> 1 from nba_api.stats.endpoints._base import Endpoint
#       2 from nba_api.stats.library.http import NBAStatsHTTP
#       3 from nba_api.stats.library.parameters import LeagueID, PerModeSimple, SeasonType
#
# File /opt/homebrew/lib/python3.9/site-packages/nba_api/stats/endpoints/_base.py:5
#       2 import numpy as np
#       4 try:
# ----> 5     from pandas import DataFrame, MultiIndex
#       7     PANDAS = True
#       8 except ImportError:
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/compat/__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/compat/numpy/__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
